# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("assignment_no_2_DataSet.csv")

# %%
print("The first five rows are as follows: ")
data.head()
# Out:
# The first five rows are as follows:
#                   Email Address                Name  Roll no    PRN No.  \
# 0  shailesh.aditya@nmiet.edu.in      Aditya Bharate  TECC101  25478965P
# 1      suyog.barve@nmiet.edu.in         Suyog Barve  TECC103  72321937M
# 2   parth.bhagvate@nmiet.edu.in      parth bhagwate  TECC114  65879456M
# 3        prasadtb2967@gmail.com  Prasad Bhanusghare  TECC105  72321945B
# 4         jswarali914@gmail.com       Swarali Joshi  TECC119  72322045L
#
#    Mobile No.  First year: Sem 1  First year: Sem 2  Second year: Sem 1  \
# 0  4545879562               6.40               6.70                5.20
# 1  9209371618               6.60               7.70                8.80
# 2  5874569821               5.60               7.40                8.80
# 3  9975578060               6.50               7.20                7.80
# 4  8999819564               8.41               8.55                7.95
#
#   Second year: Sem 2   City         State
# 0                4.3  pune     Maharastra
# 1                9.9  pune    Maharashtra
# 2                9.4  pune     Maharastra
# 3                8.5  pune    Maharashtra
# 4               7.86   Pune  Maharashtra

# %%
print("The last five rows are as follows: ")
data.tail()
# Out:
# The last five rows are as follows:
#                     Email Address               Name  Roll no    PRN No.  \
# 24    rohanpawar6112005@gmail.com        Rohan Pawar  TECC166  72447692L
# 25       vansh.yeole@nmiet.edu.in       vansh yeole   TECC174  72447703K
# 26          hendsuyesha@gmail.com      suyesha Hend   TECC116  72322025F
# 27  abhishek.bhosale@nmiet.edu.in  Abhishek Bhosale   TECC106  72321950J
# 28   jaydeep.gaikwad@nmiet.edu.in   Jaydeep Gaikwad   TECC113  72322004C
#
#     Mobile No.  First year: Sem 1  First year: Sem 2  Second year: Sem 1  \
# 24  9764141523                NaN                NaN                8.86
# 25  8237623351                NaN                NaN                8.27
# 26  9767567457               9.00               8.91                8.91
# 27  7558532819               7.77               9.14                8.23
# 28  9890638774               8.67               8.45                8.50
#
#    Second year: Sem 2      City         State
# 24               9.32      pune   Maharashtra
# 25                8.5      pune  Maharashtra
# 26               9.32      pune  Maharashtra
# 27                8.5  Solapur   Maharashtra
# 28                  9      Pune  Maharashtra

# %%
data.describe()
# Out:
#          Mobile No.  First year: Sem 1  First year: Sem 2  Second year: Sem 1
# count  2.900000e+01          25.000000          25.000000           29.000000
# mean   8.498550e+09           8.150000           8.562400            8.190690
# std    1.375505e+09           1.260559           0.856107            0.998617
# min    4.545880e+09           5.600000           6.700000            5.200000
# 25%    7.499344e+09           7.450000           8.090000            7.820000
# 50%    8.999820e+09           8.410000           8.700000            8.270000
# 75%    9.658713e+09           9.100000           9.140000            8.860000
# max    9.975578e+09           9.860000          10.000000            9.730000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Email Address       29 non-null     object
#  1   Name                29 non-null     object
#  2   Roll no             29 non-null     object
#  3   PRN No.             29 non-null     object
#  4   Mobile No.          29 non-null     int64
#  5   First year: Sem 1   25 non-null     float64
#  6   First year: Sem 2   25 non-null     float64
#  7   Second year: Sem 1  29 non-null     float64
#  8   Second year: Sem 2  29 non-null     object
#  9   City                29 non-null     object
#  10  State               29 non-null     object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.6+ KB

# %%
print("The column names of the dataset are as follows: ")
data.columns
# Out:
# The column names of the dataset are as follows:
# Index(['Email Address', 'Name', 'Roll no', 'PRN No.', 'Mobile No.',
#        'First year: Sem 1', 'First year: Sem 2', 'Second year: Sem 1',
#        'Second year: Sem 2', 'City', 'State'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Email Address         0
# Name                  0
# Roll no               0
# PRN No.               0
# Mobile No.            0
# First year: Sem 1     4
# First year: Sem 2     4
# Second year: Sem 1    0
# Second year: Sem 2    0
# City                  0
# State                 0
# dtype: int64

# %%
for i in data['Roll no'].items():
    data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
data.head()
# Out:
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
# /tmp/ipykernel_6690/1071843104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Roll no'][i[0]] = data['Roll no'][i[0]][-3:]
#                   Email Address                Name Roll no    PRN No.  \
# 0  shailesh.aditya@nmiet.edu.in      Aditya Bharate     101  25478965P
# 1      suyog.barve@nmiet.edu.in         Suyog Barve     103  72321937M
# 2   parth.bhagvate@nmiet.edu.in      parth bhagwate     114  65879456M
# 3        prasadtb2967@gmail.com  Prasad Bhanusghare     105  72321945B
# 4         jswarali914@gmail.com       Swarali Joshi     119  72322045L
#
#    Mobile No.  First year: Sem 1  First year: Sem 2  Second year: Sem 1  \
# 0  4545879562               6.40               6.70                5.20
# 1  9209371618               6.60               7.70                8.80
# 2  5874569821               5.60               7.40                8.80
# 3  9975578060               6.50               7.20                7.80
# 4  8999819564               8.41               8.55                7.95
#
#   Second year: Sem 2   City         State
# 0                4.3  pune     Maharastra
# 1                9.9  pune    Maharashtra
# 2                9.4  pune     Maharastra
# 3                8.5  pune    Maharashtra
# 4               7.86   Pune  Maharashtra

# %%
sns.boxplot(y=data['First year: Sem 1'])
# Out:
# <AxesSubplot: ylabel='First year: Sem 1'>

# %%
sns.boxplot(y=data['First year: Sem 2'])
# Out:
# <AxesSubplot: ylabel='First year: Sem 2'>

# %%
sns.boxplot(y=data["Second year: Sem 1"])
# Out:
# <AxesSubplot: ylabel='Second year: Sem 1'>

# %%
sns.boxplot(y=data["Second year: Sem 2"])
# Out:
# <AxesSubplot: ylabel='Second year: Sem 2'>
